# %% [markdown]
# # **The Chat Format**
#
# In this notebook, you will explore how you can utilize the chat format to have extended conversations with chatbots personalized or specialized for specific tasks or behaviors.
#
# ## Setup

# %%
# !pip install openai panel python-dotenv
# Out:
# Requirement already satisfied: openai in c:\users\asus\anaconda3\lib\site-packages (1.65.5)
# Requirement already satisfied: panel in c:\users\asus\anaconda3\lib\site-packages (1.5.2)
# Requirement already satisfied: python-dotenv in c:\users\asus\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\asus\anaconda3\lib\site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\asus\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\asus\anaconda3\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\asus\anaconda3\lib\site-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\asus\anaconda3\lib\site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in c:\users\asus\anaconda3\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\asus\anaconda3\lib\site-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\asus\anaconda3\lib\site-packages (from openai) (4.11.0)
# Requirement already satisfied: bleach in c:\users\asus\anaconda3\lib\site-packages (from panel) (4.1.0)
# Requirement already satisfied: bokeh<3.7.0,>=3.5.0 in c:\users\asus\anaconda3\lib\site-packages (from panel) (3.6.0)
# Requirement already satisfied: linkify-it-py in c:\users\asus\anaconda3\lib\site-packages (from panel) (2.0.0)
# Requirement already satisfied: markdown in c:\users\asus\anaconda3\lib\site-packages (from panel) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\asus\anaconda3\lib\site-packages (from panel) (2.2.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\asus\anaconda3\lib\site-packages (from panel) (0.3.0)
# Requirement already satisfied: packaging in c:\users\asus\anaconda3\lib\site-packages (from panel) (24.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\asus\anaconda3\lib\site-packages (from panel) (2.2.2)
# Requirement already satisfied: param<3.0,>=2.1.0 in c:\users\asus\anaconda3\lib\site-packages (from panel) (2.1.1)
# Requirement already satisfied: pyviz-comms>=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from panel) (3.0.2)
# Requirement already satisfied: requests in c:\users\asus\anaconda3\lib\site-packages (from panel) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\asus\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\asus\anaconda3\lib\site-packages (from bokeh<3.7.0,>=3.5.0->panel) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in c:\users\asus\anaconda3\lib\site-packages (from bokeh<3.7.0,>=3.5.0->panel) (1.2.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\asus\anaconda3\lib\site-packages (from bokeh<3.7.0,>=3.5.0->panel) (1.26.4)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\asus\anaconda3\lib\site-packages (from bokeh<3.7.0,>=3.5.0->panel) (10.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\asus\anaconda3\lib\site-packages (from bokeh<3.7.0,>=3.5.0->panel) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\asus\anaconda3\lib\site-packages (from bokeh<3.7.0,>=3.5.0->panel) (6.4.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\asus\anaconda3\lib\site-packages (from bokeh<3.7.0,>=3.5.0->panel) (2022.9.0)
# Requirement already satisfied: certifi in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\asus\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\anaconda3\lib\site-packages (from pandas>=1.2->panel) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas>=1.2->panel) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\anaconda3\lib\site-packages (from pandas>=1.2->panel) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\asus\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\asus\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\asus\anaconda3\lib\site-packages (from bleach->panel) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\asus\anaconda3\lib\site-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\asus\anaconda3\lib\site-packages (from linkify-it-py->panel) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\asus\anaconda3\lib\site-packages (from markdown-it-py->panel) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\lib\site-packages (from requests->panel) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests->panel) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh<3.7.0,>=3.5.0->panel) (2.1.3)

# %%
# !pip install jupyter_bokeh
# Out:
# Collecting jupyter_bokeh
#   Using cached jupyter_bokeh-4.0.5-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: bokeh==3.* in c:\users\asus\anaconda3\lib\site-packages (from jupyter_bokeh) (3.6.0)
# Collecting ipywidgets==8.* (from jupyter_bokeh)
#   Using cached ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\asus\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in c:\users\asus\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (1.2.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\asus\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in c:\users\asus\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (24.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\asus\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\asus\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (10.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\asus\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\asus\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (6.4.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\asus\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (2022.9.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\asus\anaconda3\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\asus\anaconda3\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (8.27.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\asus\anaconda3\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets==8.*->jupyter_bokeh)
#   Using cached widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets==8.*->jupyter_bokeh)
#   Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in c:\users\asus\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\asus\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\asus\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\asus\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\asus\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\asus\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.0)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh==3.*->jupyter_bokeh) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\anaconda3\lib\site-packages (from pandas>=1.2->bokeh==3.*->jupyter_bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas>=1.2->bokeh==3.*->jupyter_bokeh) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\anaconda3\lib\site-packages (from pandas>=1.2->bokeh==3.*->jupyter_bokeh) (2023.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\asus\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\asus\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\asus\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh==3.*->jupyter_bokeh) (1.16.0)
# Requirement already satisfied: executing in c:\users\asus\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\asus\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\asus\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.2)
# Using cached jupyter_bokeh-4.0.5-py3-none-any.whl (148 kB)
# Using cached ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Using cached widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, ipywidgets, jupyter_bokeh
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.6
#     Uninstalling widgetsnbextension-3.6.6:
#       Successfully uninstalled widgetsnbextension-3.6.6
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 1.0.0
#     Uninstalling jupyterlab-widgets-1.0.0:
#       Successfully uninstalled jupyterlab-widgets-1.0.0
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.8.1
#     Uninstalling ipywidgets-7.8.1:
#       Successfully uninstalled ipywidgets-7.8.1
# Successfully installed ipywidgets-8.1.5 jupyter_bokeh-4.0.5 jupyterlab-widgets-3.0.13 widgetsnbextension-4.0.13

# %%
# !conda install jupyter_bokeh
# Out:
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed
# warning  libmamba Added empty dependency for problem type SOLVER_RULE_UPDATE
#
# LibMambaUnsatisfiableError: Encountered problems while solving:
#   - nothing provides package_has_been_revoked needed by spyder-5.5.1-py310haa95532_1
#
# Could not solve for environment specs
# The following packages are incompatible
# ├─ _anaconda_depends is installable with the potential options
# │  ├─ _anaconda_depends [2024.02|2024.06|2024.10|2025.02|2025.03] would require
# │  │  ├─ spyder with the potential options
# │  │  │  ├─ spyder [5.5.1|6.0.1|6.0.3] would require
# │  │  │  │  └─ python-lsp-server [>=1.10.0,<1.11.0 |>=1.12.0,<1.13.0 ] with the potential options
# │  │  │  │     ├─ python-lsp-server [1.10.0|1.12.0] would require
# │  │  │  │     │  └─ yapf >=0.33.0  with the potential options
# │  │  │  │     │     ├─ yapf 0.40.2 would require
# │  │  │  │     │     │  └─ importlib-metadata >=6.6.0  with the potential options
# │  │  │  │     │     │     ├─ importlib-metadata 7.0.1, which can be installed;
# │  │  │  │     │     │     ├─ importlib-metadata [1.7.0|4.11.3|...|8.5.0] would require
# │  │  │  │     │     │     │  └─ python >=3.10,<3.11.0a0 , which can be installed;
# │  │  │  │     │     │     ├─ importlib-metadata [4.11.3|6.0.0|7.0.0|7.0.1|8.5.0] would require
# │  │  │  │     │     │     │  └─ python >=3.11,<3.12.0a0 , which can be installed;
# │  │  │  │     │     │     ├─ importlib-metadata [1.6.0|1.6.1|...|7.0.1] would require
# │  │  │  │     │     │     │  └─ python >=3.8,<3.9.0a0 , which can be installed;
# │  │  │  │     │     │     ├─ importlib-metadata [1.7.0|3.10.0|...|8.5.0] would require
# │  │  │  │     │     │     │  └─ python >=3.9,<3.10.0a0 , which can be installed;
# │  │  │  │     │     │     ├─ importlib-metadata [7.0.1|8.5.0] would require
# │  │  │  │     │     │     │  └─ python >=3.13,<3.14.0a0 , which can be installed;
# │  │  │  │     │     │     └─ importlib-metadata 8.5.0 conflicts with any installable versions previously reported;
# │  │  │  │     │     ├─ yapf 0.40.2 would require
# │  │  │  │     │     │  └─ python >=3.10,<3.11.0a0 , which can be installed;
# │  │  │  │     │     ├─ yapf 0.40.2 would require
# │  │  │  │     │     │  └─ python >=3.11,<3.12.0a0 , which can be installed;
# │  │  │  │     │     ├─ yapf 0.40.2 would require
# │  │  │  │     │     │  └─ python >=3.13,<3.14.0a0 , which can be installed;
# │  │  │  │     │     ├─ yapf 0.40.2 would require
# │  │  │  │     │     │  └─ python >=3.8,<3.9.0a0 , which can be installed;
# │  │  │  │     │     └─ yapf 0.40.2 would require
# │  │  │  │     │        └─ python >=3.9,<3.10.0a0 , which can be installed;
# │  │  │  │     ├─ python-lsp-server [1.10.0|1.12.0] would require
# │  │  │  │     │  └─ python >=3.10,<3.11.0a0 , which can be installed;
# │  │  │  │     ├─ python-lsp-server [1.10.0|1.12.0] would require
# │  │  │  │     │  └─ python >=3.11,<3.12.0a0 , which can be installed;
# │  │  │  │     ├─ python-lsp-server [1.10.0|1.12.0] would require
# │  │  │  │     │  └─ python >=3.8,<3.9.0a0 , which can be installed;
# │  │  │  │     └─ python-lsp-server [1.10.0|1.12.0] would require
# │  │  │  │        └─ python >=3.9,<3.10.0a0 , which can be installed;
# │  │  │  ├─ spyder [3.2.3|3.2.4|...|4.0.1] would require
# │  │  │  │  └─ python >=2.7,<2.8.0a0 , which can be installed;
# │  │  │  ├─ spyder [3.2.3|3.2.4|...|3.3.1] would require
# │  │  │  │  └─ python >=3.5,<3.6.0a0 , which can be installed;
# │  │  │  ├─ spyder [3.2.3|3.2.4|...|5.0.5] would require
# │  │  │  │  └─ python >=3.6,<3.7.0a0 , which can be installed;
# │  │  │  ├─ spyder [3.3.0|3.3.1|...|5.3.3] would require
# │  │  │  │  └─ python >=3.7,<3.8.0a0 , which can be installed;
# │  │  │  ├─ spyder [4.0.1|4.1.0|...|6.0.1] would require
# │  │  │  │  └─ python >=3.8,<3.9.0a0 , which can be installed;
# │  │  │  ├─ spyder [4.2.0|4.2.1|...|6.0.3] would require
# │  │  │  │  └─ python >=3.9,<3.10.0a0 , which can be installed;
# │  │  │  ├─ spyder [5.1.5|5.2.2|...|6.0.3] would require
# │  │  │  │  └─ python >=3.10,<3.11.0a0 , which can be installed;
# │  │  │  ├─ spyder [5.4.1|5.4.2|...|6.0.3] would require
# │  │  │  │  └─ python >=3.11,<3.12.0a0 , which can be installed;
# │  │  │  └─ spyder 5.5.1 would require
# │  │  │     └─ package_has_been_revoked, which does not exist (perhaps a missing channel);
# │  │  └─ streamlit with the potential options
# │  │     ├─ streamlit [1.32.0|1.33.0|...|1.42.0] would require
# │  │     │  └─ pydeck [>=0.8.0,<1 |>=0.8.0b4,<1 ] with the potential options
# │  │     │     ├─ pydeck [0.8.0|0.9.1] would require
# │  │     │     │  └─ ipywidgets >=7,<8 , which can be installed;
# │  │     │     ├─ pydeck [0.8.0|0.9.1] would require
# │  │     │     │  └─ python >=3.10,<3.11.0a0 , which can be installed;
# │  │     │     ├─ pydeck [0.8.0|0.9.1] would require
# │  │     │     │  └─ python >=3.11,<3.12.0a0 , which can be installed;
# │  │     │     ├─ pydeck 0.8.0 would require
# │  │     │     │  └─ python >=3.8,<3.9.0a0 , which can be installed;
# │  │     │     ├─ pydeck [0.8.0|0.9.1] would require
# │  │     │     │  └─ python >=3.9,<3.10.0a0 , which can be installed;
# │  │     │     └─ pydeck 0.9.1 would require
# │  │     │        └─ python >=3.13,<3.14.0a0 , which can be installed;
# │  │     ├─ streamlit [1.11.0|1.16.0|...|1.42.0] would require
# │  │     │  └─ python >=3.10,<3.11.0a0 , which can be installed;
# │  │     ├─ streamlit [1.11.0|1.16.0|...|1.42.0] would require
# │  │     │  └─ python >=3.11,<3.12.0a0 , which can be installed;
# │  │     ├─ streamlit [1.11.0|1.16.0] would require
# │  │     │  └─ python >=3.7,<3.8.0a0 , which can be installed;
# │  │     ├─ streamlit [1.11.0|1.16.0|...|1.38.0] would require
# │  │     │  └─ python >=3.8,<3.9.0a0 , which can be installed;
# │  │     ├─ streamlit [1.11.0|1.16.0|...|1.42.0] would require
# │  │     │  └─ python >=3.9,<3.10.0a0 , which can be installed;
# │  │     ├─ streamlit [1.26.1|1.27.2|1.28.2|1.29.0] would require
# │  │     │  └─ importlib-metadata >=1.4,<7  with the potential options
# │  │     │     ├─ importlib-metadata [1.7.0|4.11.3|...|8.5.0], which can be installed (as previously explained);
# │  │     │     ├─ importlib-metadata [4.11.3|6.0.0|7.0.0|7.0.1|8.5.0], which can be installed (as previously explained);
# │  │     │     ├─ importlib-metadata [1.6.0|1.6.1|...|7.0.1], which can be installed (as previously explained);
# │  │     │     ├─ importlib-metadata [1.7.0|3.10.0|...|8.5.0], which can be installed (as previously explained);
# │  │     │     ├─ importlib-metadata [1.6.0|1.6.1|...|4.8.1] would require
# │  │     │     │  └─ python >=3.6,<3.7.0a0 , which can be installed;
# │  │     │     ├─ importlib-metadata [1.6.0|1.6.1|...|4.8.2] would require
# │  │     │     │  └─ python >=3.7,<3.8.0a0 , which can be installed;
# │  │     │     └─ importlib-metadata [2.0.0|6.0.0] conflicts with any installable versions previously reported;
# │  │     ├─ streamlit [1.30.0|1.31.1] would require
# │  │     │  ├─ importlib-metadata >=1.4,<8  with the potential options
# │  │     │  │  ├─ importlib-metadata 7.0.1, which can be installed;
# │  │     │  │  ├─ importlib-metadata [1.7.0|4.11.3|...|8.5.0], which can be installed (as previously explained);
# │  │     │  │  ├─ importlib-metadata [4.11.3|6.0.0|7.0.0|7.0.1|8.5.0], which can be installed (as previously explained);
# │  │     │  │  ├─ importlib-metadata [1.6.0|1.6.1|...|7.0.1], which can be installed (as previously explained);
# │  │     │  │  ├─ importlib-metadata [1.7.0|3.10.0|...|8.5.0], which can be installed (as previously explained);
# │  │     │  │  ├─ importlib-metadata [7.0.1|8.5.0], which can be installed (as previously explained);
# │  │     │  │  ├─ importlib-metadata [1.6.0|1.6.1|...|4.8.1], which can be installed (as previously explained);
# │  │     │  │  ├─ importlib-metadata [1.6.0|1.6.1|...|4.8.2], which can be installed (as previously explained);
# │  │     │  │  └─ importlib-metadata [2.0.0|6.0.0] conflicts with any installable versions previously reported;
# │  │     │  └─ pydeck [>=0.8.0,<1 |>=0.8.0b4,<1 ], which can be installed (as previously explained);
# │  │     └─ streamlit [1.39.0|1.39.1|1.42.0] would require
# │  │        └─ python >=3.13,<3.14.0a0 , which can be installed;
# │  ├─ _anaconda_depends [2020.07|5.0.0|...|5.3.0] would require
# │  │  └─ python 3.6.* , which can be installed;
# │  ├─ _anaconda_depends [2020.07|2021.11|...|5.3.1] would require
# │  │  └─ python [3.7.* |>=3.7,<3.8.0a0 ], which can be installed;
# │  ├─ _anaconda_depends [2020.07|2021.11|...|2024.10] would require
# │  │  └─ python [3.8.* |>=3.8,<3.9.0a0 ], which can be installed;
# │  ├─ _anaconda_depends [2021.11|2022.05|...|2025.03] would require
# │  │  └─ python [3.9.* |>=3.9,<3.10.0a0 ], which can be installed;
# │  ├─ _anaconda_depends [2022.10|2023.03|...|2025.03] would require
# │  │  └─ python >=3.10,<3.11.0a0 , which can be installed;
# │  ├─ _anaconda_depends [2023.06|2023.07|...|2025.03] would require
# │  │  └─ python >=3.11,<3.12.0a0 , which can be installed;
# │  ├─ _anaconda_depends [5.0.0|5.0.1|5.1.0|5.2.0] would require
# │  │  └─ python 3.5.* , which can be installed;
# │  └─ _anaconda_depends [5.0.1|5.1.0|5.2.0|5.3.0|5.3.1] would require
# │     └─ python 2.7.* , which can be installed;
# ├─ jupyter_bokeh is installable with the potential options
# │  ├─ jupyter_bokeh [4.0.1|4.0.5] would require
# │  │  └─ ipywidgets >=8,<9  with the potential options
# │  │     ├─ ipywidgets [8.1.2|8.1.5] conflicts with any installable versions previously reported;
# │  │     ├─ ipywidgets [8.0.4|8.1.2|8.1.5] would require
# │  │     │  └─ python >=3.10,<3.11.0a0 , which can be installed;
# │  │     ├─ ipywidgets [8.0.4|8.1.2|8.1.5] would require
# │  │     │  └─ python >=3.11,<3.12.0a0 , which can be installed;
# │  │     ├─ ipywidgets [8.0.4|8.1.2] would require
# │  │     │  └─ python >=3.8,<3.9.0a0 , which can be installed;
# │  │     ├─ ipywidgets [8.0.4|8.1.2|8.1.5] would require
# │  │     │  └─ python >=3.9,<3.10.0a0 , which can be installed;
# │  │     └─ ipywidgets 8.1.5 would require
# │  │        └─ python >=3.13,<3.14.0a0 , which can be installed;
# │  ├─ jupyter_bokeh [3.0.7|4.0.1|4.0.5] would require
# │  │  └─ python >=3.10,<3.11.0a0 , which can be installed;
# │  ├─ jupyter_bokeh [3.0.7|4.0.1|4.0.5] would require
# │  │  └─ python >=3.11,<3.12.0a0 , which can be installed;
# │  ├─ jupyter_bokeh [3.0.7|4.0.1|4.0.5] would require
# │  │  └─ python >=3.8,<3.9.0a0 , which can be installed;
# │  ├─ jupyter_bokeh [3.0.7|4.0.1|4.0.5] would require
# │  │  └─ python >=3.9,<3.10.0a0 , which can be installed;
# │  └─ jupyter_bokeh 4.0.5 would require
# │     └─ python >=3.13,<3.14.0a0 , which can be installed;
# └─ pin-1 is not installable because it requires
#    └─ python 3.12.* , which conflicts with any installable versions previously reported.
#
# Pins seem to be involved in the conflict. Currently pinned specs:
#  - python 3.12.* (labeled as 'pin-1')

# %%
from openai import OpenAI
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

OPENAI_API_KEY  = os.getenv('OPENAI_API_KEY')

# %%
client = OpenAI(
    # This is the default and can be omitted
    api_key=OPENAI_API_KEY,
)

def get_completion(prompt, model="gpt-3.5-turbo", temperature=0): 
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature, 
    )
    return response.choices[0].message.content


def get_completion_from_messages(message, model="gpt-3.5-turbo", temperature=0): 
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature, 
    )
    return response.choices[0].message.content

# %%
messages =  [  
{'role':'system', 'content':'You are an assistant that speaks like Shakespeare.'},    
{'role':'user', 'content':'tell me a joke'},   
{'role':'assistant', 'content':'Why did the chicken cross the road'},   
{'role':'user', 'content':'I don\'t know'}  ]

# %%
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# To get to the other side, perchance! 'Tis a classic jest among the fowl and the jesters alike.

# %%
messages =  [  
{'role':'system', 'content':'You are friendly chatbot.'},    
{'role':'user', 'content':'Hi, my name is Isa'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# Hello Isa! It's nice to meet you. How can I assist you today?

# %%
messages =  [  
{'role':'system', 'content':'You are friendly chatbot.'},    
{'role':'user', 'content':'Yes,  can you remind me, What is my name?'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# I'm sorry, but I can't remember your name as I'm just a computer program. Could you please remind me?

# %%
messages =  [  
{'role':'system', 'content':'You are friendly chatbot.'},
{'role':'user', 'content':'Hi, my name is Isa'},
{'role':'assistant', 'content': "Hi Isa! It's nice to meet you. \
Is there anything I can help you with today?"},
{'role':'user', 'content':'Yes, you can remind me, What is my name?'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)
# Out:
# Your name is Isa.

# %% [markdown]
# # OrderBot
# We can automate the collection of user prompts and assistant responses to build a  OrderBot. The OrderBot will take orders at a pizza restaurant.

# %%
def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context) 
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600, styles={'background-color': '#F6F6F6'})))
 
    return pn.Column(*panels)

# %%
import panel as pn  # GUI
pn.extension()

panels = [] # collect display 

context = [ {'role':'system', 'content':"""
You are OrderBot, an automated service to collect orders for a pizza restaurant. \
You first greet the customer, then collects the order, \
and then asks if it's a pickup or delivery. \
You wait to collect the entire order, then summarize it and check for a final \
time if the customer wants to add anything else. \
If it's a delivery, you ask for an address. \
Finally you collect the payment.\
Make sure to clarify all options, extras and sizes to uniquely \
identify the item from the menu.\
You respond in a short, very conversational friendly style. \
The menu includes \
pepperoni pizza  12.95, 10.00, 7.00 \
cheese pizza   10.95, 9.25, 6.50 \
eggplant pizza   11.95, 9.75, 6.75 \
fries 4.50, 3.50 \
greek salad 7.25 \
Toppings: \
extra cheese 2.00, \
mushrooms 1.50 \
sausage 3.00 \
canadian bacon 3.50 \
AI sauce 1.50 \
peppers 1.00 \
Drinks: \
coke 3.00, 2.00, 1.00 \
sprite 3.00, 2.00, 1.00 \
bottled water 5.00 \
"""} ]  # accumulate messages


inp = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="Chat!")

interactive_conversation = pn.bind(collect_messages, button_conversation)

dashboard = pn.Column(
    inp,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=300),
)

dashboard.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11936\781706477.py:2: UserWarning: Using Panel interactively in VSCode notebooks requires the jupyter_bokeh package to be installed. You can install it with:
#
#    pip install jupyter_bokeh
#
# or:
#     conda install jupyter_bokeh
#
# and try again.
#   pn.extension()
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a4e7ec3d-ae61-43c2-85ab-3f58470585e4'>
#   <div id="a8cae1f1-01c7-4709-8fa7-27621e5cd3cd" data-root-id="a4e7ec3d-ae61-43c2-85ab-3f58470585e4" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f3ad934a-709a-45c4-89f0-1689fe0242b5":{"version":"3.6.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"a4e7ec3d-ae61-43c2-85ab-3f58470585e4"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"c2c5deb8-f6c1-4ace-9ae6-6d741ccedf59","attributes":{"plot_id":"a4e7ec3d-ae61-43c2-85ab-3f58470585e4","comm_id":"41b576e796d74bd2ba331d63be1fe4cd","client_comm_id":"70363f7cadeb45f2b053f77157f17874"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"f3ad934a-709a-45c4-89f0-1689fe0242b5","roots":{"a4e7ec3d-ae61-43c2-85ab-3f58470585e4":"a8cae1f1-01c7-4709-8fa7-27621e5cd3cd"},"root_ids":["a4e7ec3d-ae61-43c2-85ab-3f58470585e4"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Launching server at http://localhost:51577
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' content: {'events': [{'kind': 'MessageSent', 'msg_type': 'bokeh_event', 'msg_data': {'type': 'event', 'name': 'button_click', 'values': {'type': 'map', 'entries': [['model', {'id': '69b0e0d2-eb18-4891-9196-25a3a1edcd1a'}]]}}}]}
#  error: NameError("name 'openai' is not defined")
# Traceback (most recent call last):
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\bokeh\server\protocol_handler.py", line 94, in handle
#     work = await handler(message, connection)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\bokeh\server\session.py", line 94, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\bokeh\server\session.py", line 286, in _handle_patch
#     message.apply_to_document(self.document, self)
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\bokeh\protocol\messages\patch_doc.py", line 104, in apply_to_document
#     invoke_with_curdoc(doc, lambda: doc.apply_json_patch(self.payload, setter=setter))
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\bokeh\document\callbacks.py", line 453, in invoke_with_curdoc
#     return f()
#            ^^^
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\bokeh\protocol\messages\patch_doc.py", line 104, in <lambda>
#     invoke_with_curdoc(doc, lambda: doc.apply_json_patch(self.payload, setter=setter))
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\bokeh\document\document.py", line 391, in apply_json_patch
#     DocumentPatchedEvent.handle_event(self, event, setter)
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\bokeh\document\events.py", line 244, in handle_event
#     event_cls._handle_event(doc, event)
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\bokeh\document\events.py", line 279, in _handle_event
#     cb(event.msg_data)
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\bokeh\document\callbacks.py", line 400, in trigger_event
#     model._trigger_event(event)
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\bokeh\util\callback_manager.py", line 111, in _trigger_event
#     self.document.callbacks.notify_event(cast(Model, self), event, invoke)
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\bokeh\document\callbacks.py", line 262, in notify_event
#     invoke_with_curdoc(doc, callback_invoker)
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\bokeh\document\callbacks.py", line 453, in invoke_with_curdoc
#     return f()
#            ^^^
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\bokeh\util\callback_manager.py", line 107, in invoke
#     cast(EventCallbackWithEvent, callback)(event)
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\panel\reactive.py", line 572, in _server_event
#     self._comm_event(doc, event)
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\panel\reactive.py", line 559, in _comm_event
#     state._handle_exception(e)
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\panel\io\state.py", line 468, in _handle_exception
#     raise exception
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\panel\reactive.py", line 557, in _comm_event
#     self._process_bokeh_event(doc, event)
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\panel\reactive.py", line 494, in _process_bokeh_event
#     self._process_event(event)
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\panel\widgets\button.py", line 241, in _process_event
#     self.param.trigger('value')
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\param\parameterized.py", line 2474, in trigger
#     self_.update(dict(params, **triggers))
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\param\parameterized.py", line 2319, in update
#     restore = dict(self_._update(arg, **kwargs))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\param\parameterized.py", line 2352, in _update
#     self_._batch_call_watchers()
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\param\parameterized.py", line 2546, in _batch_call_watchers
#     self_._execute_watcher(watcher, events)
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\param\parameterized.py", line 2506, in _execute_watcher
#     watcher.fn(*args, **kwargs)
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\panel\param.py", line 891, in _replace_pane
#     new_object = self.eval(self.object)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\panel\param.py", line 1106, in eval
#     return eval_function_with_deps(ref)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\param\parameterized.py", line 165, in eval_function_with_deps
#     return function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\param\depends.py", line 53, in _depends
#     return func(*args, **kw)
#            ^^^^^^^^^^^^^^^^^
#   File "c:\Users\ASUS\anaconda3\Lib\site-packages\param\reactive.py", line 594, in wrapped
#     return eval_fn()(*combined_args, **combined_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\AppData\Local\Temp\ipykernel_11936\781706477.py", line 58, in collect_messages
#     response = get_completion_from_messages(context)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ASUS\AppData\Local\Temp\ipykernel_11936\781706477.py", line 42, in get_completion_from_messages
#     response = openai.ChatCompletion.create(
#                ^^^^^^
# NameError: name 'openai' is not defined. Did you mean: 'OpenAI'?

# %%
messages =  context.copy()
messages.append(
{'role':'system', 'content':'create a json summary of the previous food order. Itemize the price for each item\
 The fields should be 1) pizza, include size 2) list of toppings 3) list of drinks, include size   4) list of sides include size  5)total price '},    
)
 #The fields should be 1) pizza, price 2) list of toppings 3) list of drinks, include size include price  4) list of sides include size include price, 5)total price '},    

response = get_completion_from_messages(messages, temperature=0)
print(response)
# Out:
# {
#   "pizza": {
#     "type": "pepperoni pizza",
#     "size": "large"
#   },
#   "toppings": [
#     "extra cheese",
#     "mushrooms"
#   ],
#   "drinks": [
#     {
#       "type": "coke",
#       "size": "medium"
#     }
#   ],
#   "sides": [
#     {
#       "type": "fries",
#       "size": "regular"
#     }
#   ],
#   "total price": 23.45
# }

# %% [markdown]
# ## Try experimenting on your own!
#
# You can modify the menu or instructions to create your own orderbot!

# %% [markdown]
# # Exercise
#  - Complete the prompts similar to what we did in class.
#      - Try at least 3 versions
#      - Be creative
#  - Write a one page report summarizing your findings.
#      - Were there variations that didn't work well? i.e., where GPT either hallucinated or wrong
#  - What did you learn?

# %%
import os
import openai
import panel as pn  # GUI
from dotenv import load_dotenv
from openai import OpenAI  # Import OpenAI Client

# Load API Key from .env file
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")  # Fetch API key securely

# Ensure API Key exists
if not OPENAI_API_KEY:
    raise ValueError("OPENAI_API_KEY is missing! Make sure your .env file is set up correctly.")

# Initialize OpenAI Client
client = OpenAI(api_key=OPENAI_API_KEY)

# Function to generate responses
def get_completion(prompt, model="gpt-3.5-turbo", temperature=0): 
    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature, 
    )
    return response.choices[0].message.content

# Function for handling multi-message conversation
def get_completion_from_messages(messages, model="gpt-3.5-turbo", temperature=0): 
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature, 
    )
    return response.choices[0].message.content

# Initialize Panel
pn.extension()
panels = []  # Collects chat messages for display

# System message: Chatbot instructions
context = [
    {"role": "system", "content": """
You are OrderBot, an automated service for taking restaurant orders. 
Your job is to guide the customer through their order in a friendly, engaging manner.

**Ordering Process:**
1. Greet the customer and ask how you can help.
2. Ask if they want **Beef** or **Chicken** as the main dish.
3. Ask if they would like to add juice (options: **Orange, Apple, Mango**).
4. Allow customers to modify or add multiple items.
5. Summarize the order and confirm.
6. Ask if it’s for **pickup or delivery** (if delivery, request the address).
7. Confirm the **total price** and payment method (online or on delivery).

**Menu Options:**
- **Main Dishes:** 
  - Beef Meal - **$12.99**
  - Chicken Meal - **$11.99**
- **Juices:** 
  - Orange Juice - **$3.00**
  - Apple Juice - **$3.00**
  - Mango Juice - **$3.50**

**Response Guidelines:**
- Keep responses short, friendly, and conversational.
- Confirm choices clearly to avoid mistakes.
- Summarize orders before finalizing.
- If a customer asks for something unavailable, politely suggest alternatives.
"""}
]

# Function to handle chatbot messages
def collect_messages(_):
    prompt = inp.value_input  # Get user input
    inp.value = ''  # Clear input field
    context.append({'role': 'user', 'content': f"{prompt}"})  # Store user message
    
    response = get_completion_from_messages(context)  # API call
    context.append({'role': 'assistant', 'content': f"{response}"})  # Store chatbot response

    # Display user and assistant messages
    panels.append(pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(pn.Row('Assistant:', pn.pane.Markdown(response, width=600, styles={'background-color': '#F6F6F6'})))

    return pn.Column(*panels)  # Update chat UI

# Create UI components
inp = pn.widgets.TextInput(value="Hi", placeholder="Enter your order here...")
button_conversation = pn.widgets.Button(name="Chat!")

# Bind button click to function
interactive_conversation = pn.bind(collect_messages, button_conversation)

# Create chatbot interface
dashboard = pn.Column(
    inp,  # User input field
    pn.Row(button_conversation),  # Chat button
    pn.panel(interactive_conversation, loading_indicator=True, height=300),  # Chat panel
)

# Run chatbot UI
dashboard.show()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='755c4c9f-cf6d-4bc7-9500-a705e2686ad0'>
#   <div id="c7d882d9-0fec-4e9a-bb43-87fe6337a805" data-root-id="755c4c9f-cf6d-4bc7-9500-a705e2686ad0" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b16c5464-7e80-433e-8819-93e07d408704":{"version":"3.6.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"755c4c9f-cf6d-4bc7-9500-a705e2686ad0"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"06cc49ac-b2b4-4d2b-9213-9ae588f80fea","attributes":{"plot_id":"755c4c9f-cf6d-4bc7-9500-a705e2686ad0","comm_id":"2f06ae80dd734cc6a7a1d6abb47b7d86","client_comm_id":"438a003e3d1b41f69e1b8e9c10bb1c15"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"b16c5464-7e80-433e-8819-93e07d408704","roots":{"755c4c9f-cf6d-4bc7-9500-a705e2686ad0":"c7d882d9-0fec-4e9a-bb43-87fe6337a805"},"root_ids":["755c4c9f-cf6d-4bc7-9500-a705e2686ad0"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Launching server at http://localhost:51792
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 103
#      96 dashboard = pn.Column(
#      97     inp,  # User input field
#      98     pn.Row(button_conversation),  # Chat button
#      99     pn.panel(interactive_conversation, loading_indicator=True, height=300),  # Chat panel
#     100 )
#     102 # Run chatbot UI
# --> 103 dashboard.show()
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\panel\viewable.py:454, in ServableMixin.show(self, title, port, address, websocket_origin, threaded, verbose, open, location, **kwargs)
#     416 def show(
#     417     self, title: Optional[str] = None, port: int = 0, address: Optional[str] = None,
#     418     websocket_origin: Optional[str] = None, threaded: bool = False, verbose: bool = True,
#     419     open: bool = True, location: bool | 'Location' = True, **kwargs
#     420 ) -> 'StoppableThread' | 'Server':
#     421     """
#     422     Starts a Bokeh server and displays the Viewable in a new tab.
#     423
#    (...)
#     452       was launched on (if threaded=True)
#     453     """
# --> 454     return serve(
#     455         self, port=port, address=address, websocket_origin=websocket_origin,
#     456         show=open, start=True, title=title, verbose=verbose,
#     457         location=location, threaded=threaded, **kwargs
#     458     )
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\panel\io\server.py:760, in serve(panels, port, address, websocket_origin, loop, show, start, title, verbose, location, threaded, admin, **kwargs)
#     758     server.start()
#     759 else:
# --> 760     return get_server(panels, **kwargs)
#     761 return server
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\panel\io\server.py:1075, in get_server(panel, port, address, websocket_origin, loop, show, start, title, verbose, location, admin, static_dirs, basic_auth, oauth_provider, oauth_key, oauth_secret, oauth_redirect_uri, oauth_extra_params, oauth_error_template, cookie_secret, oauth_encryption_key, oauth_jwt_user, oauth_refresh_tokens, oauth_guest_endpoints, oauth_optional, login_endpoint, logout_endpoint, login_template, logout_template, session_history, liveness, warm, **kwargs)
#    1073 server.start()
#    1074 try:
# -> 1075     server.io_loop.start()
#    1076 except RuntimeError:
#    1077     pass
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\tornado\platform\asyncio.py:205, in BaseAsyncIOLoop.start(self)
#     204 def start(self) -> None:
# --> 205     self.asyncio_loop.run_forever()
#
# File c:\Users\ASUS\anaconda3\Lib\asyncio\windows_events.py:320, in ProactorEventLoop.run_forever(self)
#     318 def run_forever(self):
#     319     try:
# --> 320         assert self._self_reading_future is None
#     321         self.call_soon(self._loop_self_reading)
#     322         super().run_forever()
#
# AssertionError:
